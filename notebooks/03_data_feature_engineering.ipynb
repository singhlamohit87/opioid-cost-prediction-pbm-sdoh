# %%
import pandas as pd, numpy as np

df_geo_c = pd.read_csv("../data/cleaned/geo_2023.csv")
df_dg    = pd.read_csv("../data/cleaned/drug_geo_2023.csv")
df_sdh   = pd.read_csv("../data/cleaned/sdoh_2024.csv", header=0)

# Rebuild keys quickly
for df in [df_geo_c, df_dg]:
    if "prscrbr_geo_cd" in df.columns:
        df["fips"] = df["prscrbr_geo_cd"].astype(str).str.zfill(5)
# Out:
# /var/folders/3p/l7x9nvb10398yg6vv8kxpstr0000gn/T/ipykernel_67590/674620366.py:4: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_dg    = pd.read_csv("../data/cleaned/drug_geo_2023.csv")

# %%
# Rebuild FIPS for geo and drug_geo
for df in [df_geo_c, df_dg]:
    if "prscrbr_geo_cd" in df.columns:
        df["fips"] = df["prscrbr_geo_cd"].astype(str).str.zfill(5)
    elif "fips" in df.columns:
        df["fips"] = df["fips"].astype(str).str.zfill(5)

# For SDOH
if "fips" in df_sdh.columns:
    df_sdh["fips"] = df_sdh["fips"].astype(str).str.zfill(5)

# %%
print("geo_2023 shape:", df_geo_c.shape)
print("drug_geo shape:", df_dg.shape)
print("sdoh shape:", df_sdh.shape)

print("geo_2023 columns:", df_geo_c.columns.tolist()[:10])
print("drug_geo columns:", df_dg.columns.tolist()[:10])
print("sdoh columns:", df_sdh.columns.tolist()[:10])

print("Unique FIPS geo:", df_geo_c["fips"].nunique())
print("Unique FIPS drug_geo:", df_dg["fips"].nunique())
print("Unique FIPS sdh:", df_sdh["fips"].nunique())
# Out:
# geo_2023 shape: (328890, 20)
# drug_geo shape: (1233548, 24)
# sdoh shape: (3201, 272)
# geo_2023 columns: ['year', 'prscrbr_geo_lvl', 'prscrbr_geo_cd', 'prscrbr_geo_desc', 'ruca_cd', 'breakout_type', 'breakout', 'tot_prscrbrs', 'tot_opioid_prscrbrs', 'tot_opioid_clms']
# drug_geo columns: ['prscrbr_geo_lvl', 'prscrbr_geo_cd', 'prscrbr_geo_desc', 'brnd_name', 'gnrc_name', 'tot_prscrbrs', 'tot_clms', 'tot_30day_fills', 'tot_drug_cst', 'tot_benes']
# sdoh columns: ['fips', 'state', 'county', 'unreliable', 'deaths', 'years_of_potential_life_lost_rate', '95pct_ci___low', '95pct_ci___high', 'national_z_score', 'ypll_rate_(hispanic_(all_races))']
# Unique FIPS geo: 24551
# Unique FIPS drug_geo: 78
# Unique FIPS sdh: 3201

# %%
# Geo
if "prscrbr_geo_cd" in df_geo_c.columns:
    df_geo_c["fips"] = df_geo_c["prscrbr_geo_cd"].astype(str).str.zfill(5)

# Drug-Geo
if "prscrbr_geo_cd" in df_dg.columns:
    df_dg["fips"] = df_dg["prscrbr_geo_cd"].astype(str).str.zfill(5)

# SDOH
if "fips" in df_sdh.columns:
    df_sdh["fips"] = df_sdh["fips"].astype(str).str.zfill(5)

# Check
print("Unique FIPS in geo_2023:", df_geo_c["fips"].nunique())
print("Unique FIPS in drug_geo:", df_dg["fips"].nunique())
print("Unique FIPS in sdoh:", df_sdh["fips"].nunique())
# Out:
# Unique FIPS in geo_2023: 24551
# Unique FIPS in drug_geo: 78
# Unique FIPS in sdoh: 3201

# %%
# GEO dataset (prescribing rates by geography)
geo_keep = ["fips","year","opioid_prscrbng_rate",
            "tot_clms","tot_opioid_clms",
            "tot_prscrbrs","tot_opioid_prscrbrs",
            "la_tot_opioid_clms","la_opioid_prscrbng_rate"]
df_geo_small = df_geo_c[geo_keep]

# Drug-Geo dataset (drug costs, claims, LIS/non-LIS)
drug_keep = ["fips","year","tot_prscrbrs","tot_clms","tot_30day_fills",
             "tot_drug_cst","tot_benes","lis_bene_cst_shr","nonlis_bene_cst_shr"]
df_dg_small = df_dg[drug_keep]

# SDOH dataset (social determinants of health)
sdh_keep = ["fips","state","county","population",
            "pct_uninsured","pct_unemployed","pct_children_in_poverty","income_ratio",
            "mental_health_provider_rate","primary_care_physicians_rate",
            "pct_adults_reporting_currently_smoking","pct_adults_with_obesity",
            "pct_excessive_drinking","pct_severe_housing_problems","injury_death_rate"]
df_sdh_small = df_sdh[sdh_keep]

# %%
print(panel["fips"].dtype, df_sdh["fips"].dtype)
print(panel["fips"].head())
print(df_sdh.head(10))
# Out:
# object object
# 0    01001
# 1    01003
# 2    01005
# 3    01007
# 4    01009
# Name: fips, dtype: object
#     fips    state    county unreliable   deaths  \
# 0  01000  Alabama       NaN        NaN  98140.0
# 1  01001  Alabama   Autauga        NaN    942.0
# 2  01003  Alabama   Baldwin        NaN   3789.0
# 3  01005  Alabama   Barbour        NaN    579.0
# 4  01007  Alabama      Bibb        NaN    501.0
# 5  01009  Alabama    Blount        NaN   1239.0
# 6  01011  Alabama   Bullock        NaN    229.0
# 7  01013  Alabama    Butler        NaN    449.0
# 8  01015  Alabama   Calhoun        NaN   2735.0
# 9  01017  Alabama  Chambers        NaN    767.0
#
#    years_of_potential_life_lost_rate  95pct_ci___low  95pct_ci___high  \
# 0                       11415.734833    11307.652847     11523.816818
# 1                        9407.948438     8508.880150     10307.016727
# 2                        8981.575353     8514.700923      9448.449784
# 3                       13138.848362    11474.734018     14802.962705
# 4                       12675.434581    10964.290135     14386.579028
# 5                       11541.495069    10559.146975     12523.843162
# 6                       13837.899207    11157.326711     16518.471703
# 7                       12718.633185    10883.615238     14553.651132
# 8                       13197.258124    12445.452982     13949.063266
# 9                       12135.481512    10734.196454     13536.766570
#
#    national_z_score  ypll_rate_(hispanic_(all_races))  ...  \
# 0               NaN                               NaN  ...
# 1         -0.158592                               NaN  ...
# 2         -0.282176                       4784.741236  ...
# 3          0.922816                               NaN  ...
# 4          0.788495                               NaN  ...
# 5          0.459820                               NaN  ...
# 6          1.125437                               NaN  ...
# 7          0.801016                               NaN  ...
# 8          0.939746                               NaN  ...
# 9          0.631988                               NaN  ...
#
#    pct_drive_alone_(hispanic)_95pct_ci___low  \
# 0                                        NaN
# 1                                        NaN
# 2                                  52.360312
# 3                                        NaN
# 4                                        NaN
# 5                                  25.999308
# 6                                        NaN
# 7                                        NaN
# 8                                  83.266862
# 9                                        NaN
#
#    pct_drive_alone_(hispanic)_95pct_ci___high  pct_drive_alone_(white)  \
# 0                                         NaN                      NaN
# 1                                         NaN                80.846691
# 2                                   72.248027                80.137935
# 3                                         NaN                84.432651
# 4                                         NaN                      NaN
# 5                                  100.000000                77.894111
# 6                                         NaN                88.255916
# 7                                         NaN                88.402878
# 8                                  100.000000                86.619951
# 9                                         NaN                85.296755
#
#    pct_drive_alone_(white)_95pct_ci___low  \
# 0                                     NaN
# 1                               75.707887
# 2                               78.359852
# 3                               80.693766
# 4                                     NaN
# 5                               73.628168
# 6                               85.063040
# 7                               85.219712
# 8                               84.699931
# 9                               78.401593
#
#    pct_drive_alone_(white)_95pct_ci___high  #_workers_who_drive_alone  \
# 0                                      NaN                  2183677.0
# 1                                85.985495                    27031.0
# 2                                81.916017                   105865.0
# 3                                88.171536                     8341.0
# 4                                      NaN                     8064.0
# 5                                82.160054                    24402.0
# 6                                91.448792                     3679.0
# 7                                91.586044                     7394.0
# 8                                88.539972                    48898.0
# 9                                92.191916                    14660.0
#
#    pct_long_commute___drives_alone  95pct_ci___low.19  95pct_ci___high.19  \
# 0                             35.2          34.770402           35.629598
# 1                             42.9          37.580831           48.219169
# 2                             37.9          35.383728           40.416272
# 3                             36.7          30.463148           42.936852
# 4                             53.8          45.204744           62.395256
# 5                             60.6          55.817688           65.382312
# 6                             45.4          31.912467           58.887533
# 7                             35.2          29.487060           40.912940
# 8                             31.1          28.318440           33.881560
# 9                             31.1          26.159987           36.040013
#
#    national_z_score.33
# 0                  NaN
# 1             0.770216
# 2             0.375235
# 3             0.280439
# 4             1.631275
# 5             2.168450
# 6             0.967707
# 7             0.161945
# 8            -0.161940
# 9            -0.161940
#
# [10 rows x 272 columns]

# %%
# Step 1: Merge drug + geo prescribing
panel = df_dg_small.merge(
    df_geo_small[["fips","year","opioid_prscrbng_rate"]],
    on=["fips","year"], how="left"
)

print("After merging drug+geo:", panel.shape)

# Step 2: Add SDOH (cross-sectional, 2024 data)
panel = panel.merge(df_sdh_small, on="fips", how="left")

print("After adding SDOH:", panel.shape)
# Out:
# After merging drug+geo: (1369020, 10)
# After adding SDOH: (1369020, 24)

# %%
print(panel.columns.tolist())
# Out:
# ['fips', 'year', 'tot_prscrbrs', 'tot_clms', 'tot_30day_fills', 'tot_drug_cst', 'tot_benes', 'lis_bene_cst_shr', 'nonlis_bene_cst_shr', 'opioid_prscrbng_rate', 'state', 'county', 'population', 'pct_uninsured', 'pct_unemployed', 'pct_children_in_poverty', 'income_ratio', 'mental_health_provider_rate', 'primary_care_physicians_rate', 'pct_adults_reporting_currently_smoking', 'pct_adults_with_obesity', 'pct_excessive_drinking', 'pct_severe_housing_problems', 'injury_death_rate']

# %%
print("Population missing %:", panel["population"].isna().mean()*100)
print("opioid_claims_share missing %:", panel["opioid_claims_share"].isna().mean()*100)
print("tot_clms missing %:", panel["tot_clms"].isna().mean()*100)

# %%
# Take population from SDOH
pop_lookup = df_sdh[["fips","population"]].drop_duplicates()

# Merge without year restriction (applies to all years in panel)
panel = panel.drop(columns=["population"], errors="ignore")
panel = panel.merge(pop_lookup, on="fips", how="left")

# Recalculate claims per 1k
eps = 1e-9
panel["claims_per_1k"] = panel["tot_opioid_clms"] / (panel["population"]/1000 + eps)

print(panel[["claims_per_1k"]].describe())

import numpy as np
eps = 1e-9  # to avoid divide-by-zero

# Recreate opioid cost (if not directly available)
panel["opioid_cost"] = panel["tot_opioid_clms"].fillna(0) * panel["cost_per_claim"].fillna(0)

# Compute per-capita cost
panel["opioid_cost_per_capita"] = (
    panel["opioid_cost"] / (panel["population"].replace(0, np.nan) + eps)
)

# Check results
print(panel["opioid_cost_per_capita"].describe())
print("Non-missing count:", panel["opioid_cost_per_capita"].notna().sum())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tot_opioid_clms'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[103], line 10
#       8 # Recalculate claims per 1k
#       9 eps = 1e-9
# ---> 10 panel["claims_per_1k"] = panel["tot_opioid_clms"] / (panel["population"]/1000 + eps)
#      12 print(panel[["claims_per_1k"]].describe())
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'tot_opioid_clms'

# %%
print(df_sdh.columns.tolist())
print(df_sdh[["fips","population"]].head())
# Out:
# ['fips', 'state', 'county', 'unreliable', 'deaths', 'years_of_potential_life_lost_rate', '95pct_ci___low', '95pct_ci___high', 'national_z_score', 'ypll_rate_(hispanic_(all_races))', 'ypll_rate_(hispanic_(all_races))_95pct_ci___low', 'ypll_rate_(hispanic_(all_races))_95pct_ci___high', 'ypll_rate_(hispanic_(all_races))_unreliable', 'ypll_rate_(non_hispanic_aian)', 'ypll_rate_(non_hispanic_aian)_95pct_ci___low', 'ypll_rate_(non_hispanic_aian)_95pct_ci___high', 'ypll_rate_(non_hispanic_aian)_unreliable', 'ypll_rate_(non_hispanic_asian)', 'ypll_rate_(non_hispanic_asian)_95pct_ci___low', 'ypll_rate_(non_hispanic_asian)_95pct_ci___high', 'ypll_rate_(non_hispanic_asian)_unreliable', 'ypll_rate_(non_hispanic_black)', 'ypll_rate_(non_hispanic_black)_95pct_ci___low', 'ypll_rate_(non_hispanic_black)_95pct_ci___high', 'ypll_rate_(non_hispanic_black)_unreliable', 'ypll_rate_(non_hispanic_native_hawaiian_and_other_pacific_islande ', 'ypll_rate_(non_hispanic_native_hawaiian_and_other_pacific_islande _95pct_ci___low', 'ypll_rate_(non_hispanic_native_hawaiian_and_other_pacific_islande _95pct_ci___high', 'ypll_rate_(non_hispanic_native_hawaiian_and_other_pacific_islande _unreliable', 'ypll_rate_(non_hispanic_2+_races)', 'ypll_rate_(non_hispanic_2+_races)_95pct_ci___low', 'ypll_rate_(non_hispanic_2+_races)_95pct_ci___high', 'ypll_rate_(non_hispanic_2+_races)_unreliable', 'ypll_rate_(non_hispanic_white)', 'ypll_rate_(non_hispanic_white)_95pct_ci___low', 'ypll_rate_(non_hispanic_white)_95pct_ci___high', 'ypll_rate_(non_hispanic_white)_unreliable', 'pct_fair_or_poor_health', '95pct_ci___low.1', '95pct_ci___high.1', 'national_z_score.1', 'average_number_of_physically_unhealthy_days', '95pct_ci___low.2', '95pct_ci___high.2', 'national_z_score.2', 'average_number_of_mentally_unhealthy_days', '95pct_ci___low.3', '95pct_ci___high.3', 'national_z_score.3', 'unreliable.1', 'pct_low_birthweight', '95pct_ci___low.4', '95pct_ci___high.4', 'national_z_score.4', 'pct_lbw_(hispanic_(all_races))', 'pct_lbw_(hispanic_(all_races))_95pct_ci___low', 'pct_lbw_(hispanic_(all_races))_95pct_ci___high', 'pct_lbw_(non_hispanic_aian)', 'pct_lbw_(non_hispanic_aian)_95pct_ci___low', 'pct_lbw_(non_hispanic_aian)_95pct_ci___high', 'pct_lbw_(non_hispanic_asian)', 'pct_lbw_(non_hispanic_asian)_95pct_ci___low', 'pct_lbw_(non_hispanic_asian)_95pct_ci___high', 'pct_lbw_(non_hispanic_black)', 'pct_lbw_(non_hispanic_black)_95pct_ci___low', 'pct_lbw_(non_hispanic_black)_95pct_ci___high', 'pct_lbw_(non_hispanic_native_hawaiian_and_other_pacific_islande ', 'pct_lbw_(non_hispanic_native_hawaiian_and_other_pacific_islande _95pct_ci___low', 'pct_lbw_(non_hispanic_native_hawaiian_and_other_pacific_islande _95pct_ci___high', 'pct_lbw_(non_hispanic_2+_races)', 'pct_lbw_(non_hispanic_2+_races)_95pct_ci___low', 'pct_lbw_(non_hispanic_2+_races)_95pct_ci___high', 'pct_lbw_(non_hispanic_white)', 'pct_lbw_(non_hispanic_white)_95pct_ci___low', 'pct_lbw_(non_hispanic_white)_95pct_ci___high', 'pct_adults_reporting_currently_smoking', '95pct_ci___low.5', '95pct_ci___high.5', 'national_z_score.5', 'pct_adults_with_obesity', '95pct_ci___low.6', '95pct_ci___high.6', 'national_z_score.6', 'food_environment_index', 'national_z_score.7', 'pct_physically_inactive', '95pct_ci___low.7', '95pct_ci___high.7', 'national_z_score.8', 'pct_with_access_to_exercise_opportunities', 'national_z_score.9', 'pct_excessive_drinking', '95pct_ci___low.8', '95pct_ci___high.8', 'national_z_score.10', '#_alcohol_impaired_driving_deaths', '#_driving_deaths', 'pct_driving_deaths_with_alcohol_involvement', '95pct_ci___low.9', '95pct_ci___high.9', 'national_z_score.11', '#_chlamydia_cases', 'chlamydia_rate', 'national_z_score.12', 'teen_birth_rate', '95pct_ci___low.10', '95pct_ci___high.10', 'national_z_score.13', 'teen_birth_rate_(hispanic_(all_races))', 'teen_birth_rate_(hispanic_(all_races))_95pct_ci___low', 'teen_birth_rate_(hispanic_(all_races))_95pct_ci___high', 'teen_birth_rate_(non_hispanic_aian)', 'teen_birth_rate_(non_hispan ...
#     fips  population
# 0  01000   3428520.0
# 1  01001     40188.0
# 2  01003    167022.0
# 3  01005     17675.0
# 4  01007     15925.0

# %%
df_sdh["fips"] = df_sdh["fips"].astype(str).str.zfill(5)
panel["fips"] = panel["fips"].astype(str).str.zfill(5)

# %%
print("Sample panel FIPS:", panel["fips"].dropna().unique()[:10])
print("Sample SDOH FIPS:", df_sdh["fips"].dropna().unique()[:10])
overlap = set(panel["fips"]).intersection(set(df_sdh["fips"]))
print("Number of overlapping FIPS:", len(overlap))
# Out:
# Sample panel FIPS: ['00nan' '001.0' '002.0' '004.0' '005.0' '006.0' '008.0' '009.0' '010.0'
#  '011.0']
# Sample SDOH FIPS: ['01000' '01001' '01003' '01005' '01007' '01009' '01011' '01013' '01015'
#  '01017']
# Number of overlapping FIPS: 0

# %%
geo_2023 = pd.read_csv("../data/cms/OpioidPrescribingRates_Geography/2023/OMT_MDCR_RY25_P04_V10_Y23_GEO.csv")
print(geo_2023.shape)
print(geo_2023.columns.tolist())
geo_2023.head(10)
# Out:
# (328890, 18)
# ['Year', 'Prscrbr_Geo_Lvl', 'Prscrbr_Geo_Cd', 'Prscrbr_Geo_Desc', 'RUCA_Cd', 'Breakout_Type', 'Breakout', 'Tot_Prscrbrs', 'Tot_Opioid_Prscrbrs', 'Tot_Opioid_Clms', 'Tot_Clms', 'Opioid_Prscrbng_Rate', 'Opioid_Prscrbng_Rate_5Y_Chg', 'Opioid_Prscrbng_Rate_1Y_Chg', 'LA_Tot_Opioid_Clms', 'LA_Opioid_Prscrbng_Rate', 'LA_Opioid_Prscrbng_Rate_5Y_Chg', 'LA_Opioid_Prscrbng_Rate_1Y_Chg']
#    Year Prscrbr_Geo_Lvl  Prscrbr_Geo_Cd Prscrbr_Geo_Desc  RUCA_Cd  \
# 0  2023        National             NaN         National      NaN
# 1  2023        National             NaN         National      NaN
# 2  2023        National             NaN         National      NaN
# 3  2023           State             1.0          Alabama      NaN
# 4  2023           State             2.0           Alaska      NaN
# 5  2023           State             4.0          Arizona      NaN
# 6  2023           State             5.0         Arkansas      NaN
# 7  2023           State             6.0       California      NaN
# 8  2023           State             8.0         Colorado      NaN
# 9  2023           State             9.0      Connecticut      NaN
#
#   Breakout_Type Breakout  Tot_Prscrbrs  Tot_Opioid_Prscrbrs  Tot_Opioid_Clms  \
# 0        Totals  Overall     1379131.0             796960.0       59311234.0
# 1   Rural/Urban    Rural      150022.0              96471.0       10433987.0
# 2   Rural/Urban    Urban     1228080.0             699913.0       48835671.0
# 3        Totals  Overall       17808.0               9741.0        1661292.0
# 4        Totals  Overall        3034.0               1880.0          73416.0
# 5        Totals  Overall       29350.0              16696.0        1213710.0
# 6        Totals  Overall       11820.0               7343.0         941497.0
# 7        Totals  Overall      139039.0              78516.0        5022505.0
# 8        Totals  Overall       23898.0              15621.0         926893.0
# 9        Totals  Overall       19204.0              10418.0         525553.0
#
#        Tot_Clms  Opioid_Prscrbng_Rate  Opioid_Prscrbng_Rate_5Y_Chg  \
# 0  1.614516e+09                  3.67                        -1.01
# 1  2.765332e+08                  3.77                        -1.04
# 2  1.337145e+09                  3.65                        -1.01
# 3  3.058605e+07                  5.43                        -1.47
# 4  1.812674e+06                  4.05                        -1.77
# 5  2.859759e+07                  4.24                        -1.38
# 6  1.917052e+07                  4.91                        -0.99
# 7  1.458988e+08                  3.44                        -1.15
# 8  1.922503e+07                  4.82                        -1.30
# 9  1.823245e+07                  2.88                        -0.68
#
#    Opioid_Prscrbng_Rate_1Y_Chg  LA_Tot_Opioid_Clms  LA_Opioid_Prscrbng_Rate  \
# 0                        -0.21           5266348.0                     8.88
# 1                        -0.20            859739.0                     8.24
# 2                        -0.21           5063859.0                    10.37
# 3                        -0.26            101471.0                     6.11
# 4                        -0.34              9244.0                    12.59
# 5                        -0.27            130736.0                    10.77
# 6                        -0.20             54862.0                     5.83
# 7                        -0.26            437224.0                     8.71
# 8                        -0.23            113448.0                    12.24
# 9                        -0.18             63419.0                    12.07
#
#    LA_Opioid_Prscrbng_Rate_5Y_Chg  LA_Opioid_Prscrbng_Rate_1Y_Chg
# 0                           -2.91                           -0.49
# 1                           -2.81                           -0.47
# 2                           -2.70                           -0.46
# 3                           -2.25                           -0.38
# 4                           -6.04                           -0.86
# 5                           -4.03                           -0.57
# 6                           -2.73                           -0.46
# 7                           -2.55                           -0.38
# 8                           -1.96                           -0.05
# 9                           -2.85                           -0.51

# %%
# !pip3 install us
# Out:
# Collecting us
#   Downloading us-3.2.0-py3-none-any.whl.metadata (10 kB)
# Collecting jellyfish (from us)
#   Downloading jellyfish-1.2.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.6 kB)
# Downloading us-3.2.0-py3-none-any.whl (13 kB)
# Downloading jellyfish-1.2.0-cp313-cp313-macosx_11_0_arm64.whl (322 kB)
# Installing collected packages: jellyfish, us
# Successfully installed jellyfish-1.2.0 us-3.2.0
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip3 install --upgrade pip

# %%
import pandas as pd
import us  # pip install us

# Read raw file
geo_2023 = pd.read_csv(
    "../data/cms/OpioidPrescribingRates_Geography/2023/OMT_MDCR_RY25_P04_V10_Y23_GEO.csv",
    dtype=str  # force all columns to string at load
)

# Convert numerics back later if needed
numeric_cols = ["Tot_Clms","Tot_Opioid_Clms","Tot_Prscrbrs","Tot_Opioid_Prscrbrs",
                "Opioid_Prscrbng_Rate","LA_Opioid_Prscrbng_Rate","Year"]
for c in numeric_cols:
    if c in geo_2023.columns:
        geo_2023[c] = pd.to_numeric(geo_2023[c], errors="coerce")

# Ensure these two are always strings
geo_2023["Prscrbr_Geo_Lvl"] = geo_2023["Prscrbr_Geo_Lvl"].fillna("").astype(str)
geo_2023["Prscrbr_Geo_Desc"] = geo_2023["Prscrbr_Geo_Desc"].fillna("").astype(str)

# Keep only county-level rows
geo_county = geo_2023[geo_2023["Prscrbr_Geo_Lvl"].str.lower() == "county"].copy()

# Split "County, ST" into two parts
geo_county["county_name"] = geo_county["Prscrbr_Geo_Desc"].apply(
    lambda x: x.split(",")[0].strip() if "," in x else None
)
geo_county["state_abbr"] = geo_county["Prscrbr_Geo_Desc"].apply(
    lambda x: x.split(",")[1].strip() if "," in x else None
)

# Map state abbreviation → state FIPS
state_fips_map = {s.abbr: s.fips for s in us.states.STATES}
geo_county["state_fips"] = geo_county["state_abbr"].map(state_fips_map)

# County FIPS
geo_county["fips"] = geo_county["Prscrbr_Geo_Cd"].astype(str).str.zfill(5)

# Rename for consistency
geo_county = geo_county.rename(columns={
    "Year": "year",
    "Tot_Clms": "tot_clms",
    "Tot_Opioid_Clms": "tot_opioid_clms",
    "Tot_Prscrbrs": "tot_prscrbrs",
    "Tot_Opioid_Prscrbrs": "tot_opioid_prscrbrs",
    "Opioid_Prscrbng_Rate": "opioid_prscrbng_rate",
    "LA_Opioid_Prscrbng_Rate": "la_opioid_prscrbng_rate"
})

print(geo_county[["fips","county_name","state_abbr","year"]].head())
print("Unique FIPS count:", geo_county["fips"].nunique())
# Out:
#       fips county_name state_abbr  year
# 171  01001        None       None  2023
# 172  01003        None       None  2023
# 173  01005        None       None  2023
# 174  01007        None       None  2023
# 175  01009        None       None  2023
# Unique FIPS count: 3202

# %%
# Load SDOH (already extracted earlier)
df_sdh = pd.read_csv(
    "../data/cleaned/sdoh_2024.csv",
   header=0
)

# Standardize FIPS: always 5-digit string
df_sdh["fips"] = df_sdh["fips"].astype(str).str.zfill(5)

print("SDOH FIPS sample:", df_sdh["fips"].head())
print("Overlap with geo_county:", len(set(df_sdh["fips"]) & set(geo_county["fips"])))
# Out:
# SDOH FIPS sample: 0    01000
# 1    01001
# 2    01003
# 3    01005
# 4    01007
# Name: fips, dtype: object
# Overlap with geo_county: 3107

# %%
print(df_sdh.columns.tolist()[:20])  # show first 20 col names
# Out:
# ['fips', 'state', 'county', 'unreliable', 'deaths', 'years_of_potential_life_lost_rate', '95pct_ci___low', '95pct_ci___high', 'national_z_score', 'ypll_rate_(hispanic_(all_races))', 'ypll_rate_(hispanic_(all_races))_95pct_ci___low', 'ypll_rate_(hispanic_(all_races))_95pct_ci___high', 'ypll_rate_(hispanic_(all_races))_unreliable', 'ypll_rate_(non_hispanic_aian)', 'ypll_rate_(non_hispanic_aian)_95pct_ci___low', 'ypll_rate_(non_hispanic_aian)_95pct_ci___high', 'ypll_rate_(non_hispanic_aian)_unreliable', 'ypll_rate_(non_hispanic_asian)', 'ypll_rate_(non_hispanic_asian)_95pct_ci___low', 'ypll_rate_(non_hispanic_asian)_95pct_ci___high']

# %%
df_sdh["fips"] = df_sdh["fips"].astype(str).str.split(".").str[0].str.zfill(5)

# %%
for df in [df_geo_c, df_prescribers, df_dg]:
    if "prscrbr_geo_cd" in df.columns:
        df["fips"] = df["prscrbr_geo_cd"].astype(str).str.split(".").str[0].str.zfill(5)

# %%
print("Sample FIPS in CMS:", df_geo_c["fips"].dropna().unique()[:10])
print("Sample FIPS in SDOH:", df_sdh["fips"].dropna().unique()[:10])
# Out:
# Sample FIPS in CMS: ['00nan' '00001' '00002' '00004' '00005' '00006' '00008' '00009' '00010'
#  '00011']
# Sample FIPS in SDOH: ['01000' '01001' '01003' '01005' '01007' '01009' '01011' '01013' '01015'
#  '01017']

# %%
overlap = set(df_geo_c["fips"]).intersection(set(df_sdh["fips"]))
print("Number of overlapping FIPS:", len(overlap))
# Out:
# Number of overlapping FIPS: 3124

# %%
print(panel.columns.tolist())
# Out:
# ['fips', 'year', 'tot_prscrbrs', 'tot_clms', 'tot_30day_fills', 'tot_drug_cst', 'tot_benes', 'lis_bene_cst_shr', 'nonlis_bene_cst_shr', 'opioid_prscrbng_rate', 'state', 'county', 'pct_uninsured', 'pct_unemployed', 'pct_children_in_poverty', 'income_ratio', 'mental_health_provider_rate', 'primary_care_physicians_rate', 'pct_adults_reporting_currently_smoking', 'pct_adults_with_obesity', 'pct_excessive_drinking', 'pct_severe_housing_problems', 'injury_death_rate', 'population']

# %%
# Fix malformed FIPS in panel
import numpy as np

# 1. Keep only the useful columns from df_geo
geo_keep = [
    "fips", "year", "tot_clms", "tot_opioid_clms",
    "tot_prscrbrs", "tot_opioid_prscrbrs", "opioid_prscrbng_rate"
]
df_geo_small = df_geo_c[geo_keep].copy()

# 2. Select SDOH features
sdh_keep = [
    "fips","state","county","population",
    "pct_uninsured","pct_unemployed","pct_children_in_poverty","income_ratio",
    "mental_health_provider_rate","primary_care_physicians_rate",
    "pct_adults_reporting_currently_smoking","pct_adults_with_obesity",
    "pct_excessive_drinking","pct_severe_housing_problems","injury_death_rate"
]
df_sdh_small = df_sdh[sdh_keep].copy()

# 3. Merge CMS + SDOH
panel = df_geo_small.merge(df_sdh_small, on="fips", how="left")

# 4. Feature engineering
eps = 1e-9
panel["opioid_claims_share"] = panel["tot_opioid_clms"] / (panel["tot_clms"] + eps)
panel["cost_per_claim"] = panel["tot_opioid_clms"] / (panel["tot_prscrbrs"] + eps)

if "population" in panel.columns:
    panel["claims_per_1k"] = panel["tot_opioid_clms"] / (panel["population"]/1000 + eps)

# Log transforms to reduce skew
for c in ["Tot_Clms","Tot_Opioid_Clms","claims_per_1k"]:
    if c in panel.columns:
        panel[f"log1p_{c}"] = np.log1p(panel[c])

print("Final panel shape:", panel.shape)
print(panel.head())
# Out:
# Final panel shape: (328890, 25)
#     fips  year      tot_clms  tot_opioid_clms  tot_prscrbrs  \
# 0  00nan  2023  1.614516e+09       59311234.0     1379131.0
# 1  00nan  2023  2.765332e+08       10433987.0      150022.0
# 2  00nan  2023  1.337145e+09       48835671.0     1228080.0
# 3  00001  2023  3.058605e+07        1661292.0       17808.0
# 4  00002  2023  1.812674e+06          73416.0        3034.0
#
#    tot_opioid_prscrbrs  opioid_prscrbng_rate state county  population  ...  \
# 0             796960.0                  3.67   NaN    NaN         NaN  ...
# 1              96471.0                  3.77   NaN    NaN         NaN  ...
# 2             699913.0                  3.65   NaN    NaN         NaN  ...
# 3               9741.0                  5.43   NaN    NaN         NaN  ...
# 4               1880.0                  4.05   NaN    NaN         NaN  ...
#
#    primary_care_physicians_rate  pct_adults_reporting_currently_smoking  \
# 0                           NaN                                     NaN
# 1                           NaN                                     NaN
# 2                           NaN                                     NaN
# 3                           NaN                                     NaN
# 4                           NaN                                     NaN
#
#    pct_adults_with_obesity  pct_excessive_drinking  \
# 0                      NaN                     NaN
# 1                      NaN                     NaN
# 2                      NaN                     NaN
# 3                      NaN                     NaN
# 4                      NaN                     NaN
#
#    pct_severe_housing_problems  injury_death_rate  opioid_claims_share  \
# 0                          NaN                NaN             0.036736
# 1                          NaN                NaN             0.037731
# 2                          NaN                NaN             0.036522
# 3                          NaN                NaN             0.054315
# 4                          NaN                NaN             0.040501
#
#    cost_per_claim  claims_per_1k  log1p_claims_per_1k
# 0       43.006237            NaN                  NaN
# 1       69.549713            NaN                  NaN
# 2       39.765871            NaN                  NaN
# 3       93.289084            NaN                  NaN
# 4       24.197759            NaN                  NaN
#
# [5 rows x 25 columns]

# %%
panel = panel.drop(columns=["population"], errors="ignore")
panel = panel.merge(df_sdh[["fips","population"]], on="fips", how="left")

print("Population missing % after merge:", panel["population"].isna().mean()*100)
# Out:
# Population missing % after merge: 65.68609565508224

# %%
eps = 1e-9  # to avoid divide-by-zero

# Recreate opioid cost (if not directly available)
panel["opioid_cost"] = panel["tot_opioid_clms"].fillna(0) * panel["cost_per_claim"].fillna(0)

# Compute per-capita cost
panel["opioid_cost_per_capita"] = (
    panel["opioid_cost"] / (panel["population"].replace(0, np.nan) + eps)
)

# Check results
print(panel["opioid_cost_per_capita"].describe())
print("Non-missing count:", panel["opioid_cost_per_capita"].notna().sum())
# Out:
# count    112855.000000
# mean         32.887651
# std         107.745060
# min           0.000000
# 25%           0.000000
# 50%           9.652977
# 75%          33.831463
# max        6490.470000
# Name: opioid_cost_per_capita, dtype: float64
# Non-missing count: 112855

# %%
print(panel.columns.tolist())
# Out:
# ['fips', 'year', 'tot_clms', 'tot_opioid_clms', 'tot_prscrbrs', 'tot_opioid_prscrbrs', 'opioid_prscrbng_rate', 'state', 'county', 'pct_uninsured', 'pct_unemployed', 'pct_children_in_poverty', 'income_ratio', 'mental_health_provider_rate', 'primary_care_physicians_rate', 'pct_adults_reporting_currently_smoking', 'pct_adults_with_obesity', 'pct_excessive_drinking', 'pct_severe_housing_problems', 'injury_death_rate', 'opioid_claims_share', 'cost_per_claim', 'claims_per_1k', 'log1p_claims_per_1k', 'population', 'opioid_cost', 'opioid_cost_per_capita']

# %%
#Save engineered dataset
out_path = "../data/cleaned/feature_engineered_panel.csv"
panel.to_csv(out_path, index=False)
print(f"Saved feature engineered dataset: {out_path}, shape: {panel.shape}")
# Out:
# Saved feature engineered dataset: ../data/cleaned/feature_engineered_panel.csv, shape: (328890, 27)

# %%
#Save engineered dataset
out_path = "../data/cleaned/feature_engineered_panel.csv"
panel.to_csv(out_path, index=False)
print(f"Saved feature engineered dataset: {out_path}, shape: {panel.shape}")
# Out:
# Saved feature engineered dataset: ../data/cleaned/feature_engineered_panel.csv, shape: (328890, 25)

# %%
#Quick sanity checks
print(panel.head())
print(panel.describe(include="all").T)
# Out:
#     fips  year      tot_clms  tot_opioid_clms  tot_prscrbrs  \
# 0  00nan  2023  1.614516e+09       59311234.0     1379131.0
# 1  00nan  2023  2.765332e+08       10433987.0      150022.0
# 2  00nan  2023  1.337145e+09       48835671.0     1228080.0
# 3  00001  2023  3.058605e+07        1661292.0       17808.0
# 4  00002  2023  1.812674e+06          73416.0        3034.0
#
#    tot_opioid_prscrbrs  opioid_prscrbng_rate state county  pct_uninsured  ...  \
# 0             796960.0                  3.67   NaN    NaN            NaN  ...
# 1              96471.0                  3.77   NaN    NaN            NaN  ...
# 2             699913.0                  3.65   NaN    NaN            NaN  ...
# 3               9741.0                  5.43   NaN    NaN            NaN  ...
# 4               1880.0                  4.05   NaN    NaN            NaN  ...
#
#    pct_excessive_drinking  pct_severe_housing_problems  injury_death_rate  \
# 0                     NaN                          NaN                NaN
# 1                     NaN                          NaN                NaN
# 2                     NaN                          NaN                NaN
# 3                     NaN                          NaN                NaN
# 4                     NaN                          NaN                NaN
#
#    opioid_claims_share  cost_per_claim  claims_per_1k  log1p_claims_per_1k  \
# 0             0.036736       43.006237            NaN                  NaN
# 1             0.037731       69.549713            NaN                  NaN
# 2             0.036522       39.765871            NaN                  NaN
# 3             0.054315       93.289084            NaN                  NaN
# 4             0.040501       24.197759            NaN                  NaN
#
#    population   opioid_cost  opioid_cost_per_capita
# 0         NaN  2.550753e+09                     NaN
# 1         NaN  7.256808e+08                     NaN
# 2         NaN  1.941993e+09                     NaN
# 3         NaN  1.549804e+08                     NaN
# 4         NaN  1.776503e+06                     NaN
#
# [5 rows x 27 columns]
#                                            count unique         top  freq  \
# fips                                      328890  24551       48467    44
# year                                    328890.0    NaN         NaN   NaN
# tot_clms                                323970.0    NaN         NaN   NaN
# tot_opioid_clms                         308372.0    NaN         NaN   NaN
# tot_prscrbrs                            323970.0    NaN         NaN   NaN
# tot_opioid_prscrbrs                     323970.0    NaN         NaN   NaN
# opioid_prscrbng_rate                    281846.0    NaN         NaN   NaN
# state                                     112908     51       Texas  9431
# county                                    112908   1841  Washington  1088
# pct_uninsured                           112844.0    NaN         NaN   NaN
# pct_unemployed                          112844.0    NaN         NaN   NaN
# pct_children_in_poverty                 112844.0    NaN         NaN   NaN
# income_ratio                            112349.0    NaN         NaN   NaN
# mental_health_provider_rate             106648.0    NaN         NaN   NaN
# primary_care_physicians_rate            107632.0    NaN         NaN   NaN
# pct_adults_reporting_currently_smoking  112855.0    NaN         NaN   NaN
# pct_adults_with_obesity                 112855.0    NaN         NaN   NaN
# pct_excessive_drinking                  112855.0    NaN         NaN   NaN
# pct_severe_housing_problems             112855.0    NaN         NaN   NaN
# injury_death_rate                       110140.0    NaN         NaN   NaN
# opioid_claims_share                     308372.0    NaN         NaN   NaN
# cost_per_claim                          308372.0    NaN         NaN   NaN
# claims_per_1k                           110358.0    NaN         NaN   NaN
# log1p_claims_per_1k                     110358.0    NaN         NaN   NaN
# population                              112855.0    NaN         NaN   NaN
# opioid_cost                             328890.0    NaN         NaN   NaN
# opioid_cost_per_capita                  112855.0    NaN         NaN   NaN
#
#                                                  mean              std  \
# fips                                              NaN              NaN
# year                                      2018.024434         3.168213
# tot_clms                                353134.892336  11573737.301925
# tot_opioid_clms                          17534.022139    562682.654479
# tot_prscrbrs                                285.21368      9647.429805
# tot_opioid_prscrbrs                        191.227277      6410.196482
# opioid_prscrbng_rate                         5.052888         5.237242
# state                                             NaN              NaN
# county                                            NaN              NaN
# pct_uninsured                               11.531267         5.269029
# pct_unemployed                                3.60283         1.223278
# pct_children_in_poverty                     19.361463         8.348098
# income_ratio                                 4.550611         0.792567
# mental_health_provider_rate                200.534278       222.010647
# primary_care_physicians_rate                54.057874        36.567687
# pct_adults_reporting_currently_smoking      19.018305         4.080896
# pct_adults_with_obesity                     37.324348          4.59486
# pct_excessive_drinking                      16.896065         2.642495
# pct_severe_housing_problems                 12.875151         4.405719
# injury_death_rate                           96.004769        28.353643
# opioid_claims_share                          0.046182         0.052035
# cost_per_claim                              84.639707       122.238826
# claims_per_1k                              255.598815       816.203354
# log1p_claims_per_1k                           3.88219         2.504009
# population                               74068.924567    238951.444421
# opioid_cost                             1267795.00731  34323566.172024
# opioid_cost_per_capita                      32.887651        107.74506
#
#                                               min          25%           50%  \
# fips                                          NaN          NaN           NaN
# year                                       2013.0       2015.0        2018.0
# tot_clms                                      0.0       2995.0       28080.0
# tot_opioid_clms                               0.0        145.0        1257.0
# tot_prscrbrs                                  0.0          3.0          15.0
# tot_opioid_prscrbrs                           0.0          2.0          11.0
# opioid_prscrbng_rate                          0.0         2.66          4.17
# state                                         NaN          NaN           NaN
# county                                        NaN          NaN           NaN
# pct_uninsured                            2.389743     7.453416     10.436079
# pct_unemployed                           0.572082     2.740402      3.420129
# pct_children_in_poverty                       2.4         13.3         18.05
# income_ratio                              2.26575     4.017448      4.430398
# mental_health_provider_rate                   0.0     62.26651     138.66589
# primary_care_physicians_rate                  0.0     29.95267       47.3495
# pct_adults_reporting_currently_smoking        7.0         16.4          18.7
# pct_adults_with_obesity                      17.4         35.0          37.6
# pct_excessive_drinking                   9.038096     15.06072     16.907238
# pct_severe_housing_problems                   0.0    10.218978     12.257817
# injury_death_rate                       29.515939    76.678588     93.524393
# opioid_claims_share                           0.0     0.021036      0.038942
# cost_per_claim                                0.0    19.785364     55.583333
# claims_per_1k                                 0.0     0.793945    153.824836
# log1p_claims_per_1k                           0.0     0.584417      5.042294
# population                                   50.0       7977.0       18457.0
# opioid_cost                                   0.0  1104.499999  70577.052628
# opioid_cost_per_capita                        0.0          0.0      9.652977
#
#                                                   75%                max
# fips                                              NaN                NaN
# year                                           2021.0             2023.0
# tot_clms                                     110191.5       1614516164.0
# tot_opioid_clms                               5165.25         81034560.0
# tot_prscrbrs                                     66.0          1379131.0
# tot_opioid_prscrbrs                              44.0           820959.0
# opioid_prscrbng_rate                             5.94              100.0
# state                                             NaN                NaN
# county                                            NaN                NaN
# pct_uninsured                               14.607811          38.712446
# pct_unemployed                               4.209584          14.667733
# pct_children_in_poverty                          24.0               88.7
# income_ratio                                 4.942808          10.532338
# mental_health_provider_rate                 259.29536         3407.85637
# primary_care_physicians_rate                  71.2293          580.52745
# pct_adults_reporting_currently_smoking           21.5               43.0
# pct_adults_with_obesity                          40.3               52.5
# pct_excessive_drinking                      18.547806          26.797762
# pct_severe_housing_problems                 14.772727          61.142857
# injury_death_rate                          110.990918         315.568022
# opioid_claims_share                          0.057284                1.0
# cost_per_claim                             108.457776        5202.999995
# claims_per_1k                              333.478573       43053.612953
# log1p_claims_per_1k                          5.812573          10.670225
# population                                    48059.0          6909650.0
# opioid_cost                             453856.095227  6126022502.067409
# opioid_cost_per_capita                      33.831463            6490.47
